# %% [markdown]
# #1. What is hypothesis testing in statistics*
#
# - Hypothesis testing is a statistical method used to determine whether there is enough evidence to reject a presumed assumption (hypothesis) about a population parameter.

# %% [markdown]
# #2 What is the null hypothesis, and how does it differ from the alternative hypothesis*
#
# - Null Hypothesis (H₀): Assumes no effect or no difference in the population.
#
# - Alternative Hypothesis (H₁): Suggests a significant effect or difference exists.

# %% [markdown]
# #3. What is the significance level in hypothesis testing, and why is it important.
#
#  The probability of rejecting H₀ when it is actually true (Type 1 error).
#
# - Common values: 0.05 (5%) or 0.01 (1%).
#
# - A lower α reduces the likelihood of a Type 1 error but increases the risk of
#  a Type 2 error

# %% [markdown]
# #4. What does a P-value represent in hypothesis testing.
#
# The probability of obtaining a test result at least as extreme as the observed result, assuming H₀ is true.
#
# - A small P-value (≤ α) suggests strong evidence against H₀, leading to rejection of H₀.
#
# - A large P-value (> α) suggests insufficient evidence to reject H₀.

# %% [markdown]
# #5.  How do you interpret the P-value in hypothesis testing*
#
# - P ≤ α: Reject H₀ (statistically significant result).
#
# - P > α: Fail to reject H₀ (not statistically significant).
# For example, if P = 0.03 and α = 0.05, we reject H₀ and conclude that there is a statistically significant effect.

# %% [markdown]
# #6. What are Type 1 and Type 2 errors in hypothesis testing.
#
# - Type 1 Error (False Positive): Rejecting a true H₀. Probability = α.
#
# - Type 2 Error (False Negative): Failing to reject a false H₀. Probability = β.
# Reducing one error type increases the risk of the other.

# %% [markdown]
# #7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing.
#
# - One-Tailed Test: Tests for an effect in one specific direction (e.g., mean is greater than a value).
#
# - Two-Tailed Test: Tests for an effect in both directions (e.g., mean is different from a value).
# A two-tailed test is used when the direction of the effect is unknown.

# %% [markdown]
# #8. What is the Z-test, and when is it used in hypothesis testing.
#
# A Z-test is used when:
#
# - The sample size is large (n ≥ 30).
#
# - The population standard deviation (σ) is known.
# It is commonly used for comparing sample and population means or proportions.

# %% [markdown]
# #9. How do you calculate the Z-score, and what does it represent in hypothesis testing.
#
# The Z-score measures how far a sample mean deviates from the population mean in standard deviations:
#
# 𝑍
# =
# (
# 𝑋
# −
# 𝜇
# )
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# (X−μ)
# ​
#
# - A high Z-score (e.g., 3 or -3) suggests the sample mean is far from the population mean.
#
# - A Z-score near 0 means the sample mean is close to the population mean.

# %% [markdown]
# #10. What is the T-distribution, and when should it be used instead of the normal distribution.
#
# A T-distribution is used instead of a normal distribution when:
#
# - The sample size is small (n < 30).
#
# - The population standard deviation (σ) is unknown.
# It has fatter tails than the normal distribution, accounting for more variability in small samples.

# %% [markdown]
# #11. What is the difference between a Z-test and a T-test.
#
# - Z-Test: Used for large samples with a known population variance.
#
# - T-Test: Used for small samples with an unknown population variance.

# %% [markdown]
# #12. What is the T-test, and how is it used in hypothesis testing.
#
# The T-test compares the means of two groups to determine if they are significantly different.
#
# - One-Sample T-Test: Compares a sample mean to a known population mean.
#
# - Independent T-Test: Compares means of two independent groups.
#
# - Paired T-Test: Compares means of the same group before and after treatment.

# %% [markdown]
# #13. What is the relationship between Z-test and T-test in hypothesis testing.
#
# - Both tests compare means, but Z-test is for large samples with known variance, while T-test is for small samples with unknown variance. As the sample size increases, the T-distribution approaches the normal distribution.

# %% [markdown]
# #14.  What is a confidence interval, and how is it used to interpret statistical results.
#
# Confidence Interval and Its Use
#
# - A confidence interval (CI) provides a range of values within which the true population parameter is expected to fall.
#
#  𝐶
# 𝐼
# =
# 𝑋
# ˉ
# ±
# (
# 𝑡
# 𝛼
# /
# 2
# ×
# 𝑠
# 𝑛
# )
# CI=
# X
# ˉ
#  ±(t
# α/2
# ​
#  ×
# n
# ​
# s)
#
#  A 95% CI means that if we repeat the experiment, 95% of the intervals would contain the true mean.

# %% [markdown]
# #15. What is the margin of error, and how does it affect the confidence interval?
#
# The margin of error (MOE) is the maximum expected difference between the sample estimate and the population parameter.
#
# 𝑀
# 𝑂
# 𝐸
# =
# 𝑡
# 𝛼
# /
# 2
# ×
# 𝑠
# 𝑛
# MOE=t
# α/2
# ​
#  ×
# n
# ​s
# ​
#
# A larger sample size reduces MOE, leading to a narrower confidence interval.

# %% [markdown]
# #16. How is Bayes' Theorem used in statistics, and what is its significance.
#
# Bayes' Theorem and Its Significance
# -
# Bayes' Theorem calculates conditional probabilities, updating beliefs with new evidence:
#
#   𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)P(A)
# ​
#
# - It is widely used in machine learning, spam filtering, and medical diagnostics.

# %% [markdown]
# #17. What is the Chi-square distribution, and when is it used.
#
# The Chi-square distribution is used for:
#
# - Goodness-of-fit tests (checking if observed data follows an expected distribution).
#
# - Independence tests (checking if two categorical variables are related).

# %% [markdown]
# #18. What is the Chi-square goodness of fit test, and how is it applied?
#
# - Used to test whether an observed frequency distribution matches an expected distribution.
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# −
# 𝐸
# )
# 2
# 𝐸
# χ
# 2
#  =∑
# E
# (O−E)
# 2
#
# ​
#
#  O: Observed frequency
#
# E: Expected frequency
# If χ² is large, it suggests a significant difference between observed and expected values.

# %% [markdown]
# #19. What is the F-distribution, and when is it used in hypothesis testing.
#
# - In probability theory and statistics, the F-distribution or F-ratio, also known as Snedecor's F distribution or the Fisher–Snedecor distribution, is a continuous probability distribution that arises frequently as the null distribution of a test statistic, most notably in the analysis of variance and other F-tests.
#
#   Used in comparing variances, particularly in ANOVA and regression analysis. The F-distribution is right-skewed and depends on two degrees of freedom.

# %% [markdown]
# #20. What is an ANOVA test, and what are its assumptions?
#
# ANOVA (Analysis of Variance) checks whether three or more group means are significantly different.
# Assumptions:
#
# - The data is normally distributed.
#
# - The groups have equal variances (homogeneity).
#
# - The samples are independent.

# %% [markdown]
# #21. What are the different types of ANOVA tests?
#
# - One-Way ANOVA: Compares means of one independent variable across multiple groups.
#
# - Two-Way ANOVA: Compares means with two independent variables.
#
# - Repeated Measures ANOVA: Compares means within the same subjects over time.

# %% [markdown]
# #22. What is the F-test, and how does it relate to hypothesis testing?
#
# - The F-test compares variances to test for equality.
#
#  𝐹
# =
# Variance of group 1
# Variance of group 2
# F=
# Variance of group 2
# Variance of group 1
# ​
#
# - If F > critical value, reject H₀ (variances are significantly different).
#
# - Used in ANOVA, regression analysis, and comparing model fit.
#
#  These statistical tests help in making informed decisions in research and data analysis

# %%
#1.Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

import scipy.stats as stats
import numpy as np

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)
    z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))  # Two-tailed test

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-Score: {z_score:.2f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < alpha:
        print("Conclusion: Reject the null hypothesis (significant difference).")
    else:
        print("Conclusion: Fail to reject the null hypothesis (no significant difference).")

# Example Usage
sample_data = [52, 48, 50, 47, 53, 51, 49, 50, 54, 46]  # Sample data
population_mean = 50  # Population mean
population_std = 3  # Population standard deviation

z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 50.00
# Z-Score: 0.00
# P-Value: 1.0000
# Conclusion: Fail to reject the null hypothesis (no significant difference).

# %%
#2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.
import numpy as np
import scipy.stats as stats

# Simulate random sample data
np.random.seed(42)  # For reproducibility
sample_size = 30
population_mean = 50
population_std = 5

sample_data = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)

# Perform Z-test
sample_mean = np.mean(sample_data)
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))  # Two-tailed test

# Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-Score: {z_score:.2f}")
print(f"P-Value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Conclusion: Reject the null hypothesis (significant difference).")
else:
    print("Conclusion: Fail to reject the null hypothesis (no significant difference).")
# Out:
# Sample Mean: 49.06
# Z-Score: -1.03
# P-Value: 0.3028
# Conclusion: Fail to reject the null hypothesis (no significant difference).

# %%
#3.  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
import numpy as np
import scipy.stats as stats

def one_sample_z_test(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)
    z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))  # Two-tailed test

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-Score: {z_score:.2f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < alpha:
        print("Conclusion: Reject the null hypothesis (significant difference).")
    else:
        print("Conclusion: Fail to reject the null hypothesis (no significant difference).")

# Example: Generate random sample data
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=5, size=30)  # Mean=50, Std=5, Size=30
population_mean = 50
population_std = 5

# Perform one-sample Z-test
one_sample_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 49.06
# Z-Score: -1.03
# P-Value: 0.3028
# Conclusion: Fail to reject the null hypothesis (no significant difference).

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def two_tailed_z_test(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)
    z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))  # Two-tailed test

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-Score: {z_score:.2f}")
    print(f"P-Value: {p_value:.4f}")

    # Decision Rule
    z_critical = stats.norm.ppf(1 - alpha/2)  # Critical value for two-tailed test
    reject_region = abs(z_score) > z_critical

    if reject_region:
        print("Conclusion: Reject the null hypothesis (significant difference).")
    else:
        print("Conclusion: Fail to reject the null hypothesis (no significant difference).")

    # Visualization
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, color='blue', label="Standard Normal Distribution")

    # Shade critical regions
    x_critical_right = np.linspace(z_critical, 4, 100)
    y_critical_right = stats.norm.pdf(x_critical_right, 0, 1)
    plt.fill_between(x_critical_right, y_critical_right, color='red', alpha=0.5, label="Rejection Region")

    x_critical_left = np.linspace(-4, -z_critical, 100)
    y_critical_left = stats.norm.pdf(x_critical_left, 0, 1)
    plt.fill_between(x_critical_left, y_critical_left, color='red', alpha=0.5)

    # Plot the Z-score
    plt.axvline(x=z_score, color='black', linestyle='dashed', label=f"Z-Score: {z_score:.2f}")

    plt.axvline(x=z_critical, color='red', linestyle='dotted', label=f"Critical Z: ±{z_critical:.2f}")
    plt.axvline(x=-z_critical, color='red', linestyle='dotted')

    plt.title("Two-Tailed Z-Test Decision Regions")
    plt.xlabel("Z-Score")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.show()

# Example: Generate random sample data
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=5, size=30)  # Mean=50, Std=5, Size=30
population_mean = 50
population_std = 5

# Perform two-tailed Z-test
two_tailed_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 49.06
# Z-Score: -1.03
# P-Value: 0.3028
# Conclusion: Fail to reject the null hypothesis (no significant difference).

# %%
#5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def visualize_type1_type2_errors(mu_null, mu_alt, sigma, alpha=0.05, n=30):
    x = np.linspace(mu_null - 4*sigma/np.sqrt(n), mu_alt + 4*sigma/np.sqrt(n), 1000)
    null_dist = stats.norm.pdf(x, mu_null, sigma/np.sqrt(n))
    alt_dist = stats.norm.pdf(x, mu_alt, sigma/np.sqrt(n))

    z_critical = stats.norm.ppf(1 - alpha)
    critical_value = mu_null + z_critical * (sigma / np.sqrt(n))

    plt.figure(figsize=(8, 5))
    plt.plot(x, null_dist, label="Null Distribution (H₀)", color='blue')
    plt.plot(x, alt_dist, label="Alternative Distribution (H₁)", color='green')

    x_type1 = np.linspace(critical_value, mu_null + 4*sigma/np.sqrt(n), 100)
    y_type1 = stats.norm.pdf(x_type1, mu_null, sigma/np.sqrt(n))
    plt.fill_between(x_type1, y_type1, color='red', alpha=0.5, label="Type 1 Error (α)")

    x_type2 = np.linspace(mu_null - 4*sigma/np.sqrt(n), critical_value, 100)
    y_type2 = stats.norm.pdf(x_type2, mu_alt, sigma/np.sqrt(n))
    plt.fill_between(x_type2, y_type2, color='orange', alpha=0.5, label="Type 2 Error (β)")

    plt.axvline(critical_value, color='black', linestyle='dashed', label=f"Critical Value: {critical_value:.2f}")
    plt.xlabel("Test Statistic")
    plt.ylabel("Probability Density")
    plt.title("Type 1 and Type 2 Errors")
    plt.legend()
    plt.show()

visualize_type1_type2_errors(mu_null=50, mu_alt=53, sigma=5, alpha=0.05, n=30)

# %%
#6. Write a Python program to perform an independent T-test and interpret the results.

import numpy as np
import scipy.stats as stats

def independent_t_test(sample1, sample2, alpha=0.05):
    t_stat, p_value = stats.ttest_ind(sample1, sample2, equal_var=False)

    print(f"T-Statistic: {t_stat:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: The means are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between means.")

np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=10, size=30)
sample2 = np.random.normal(loc=55, scale=10, size=30)

independent_t_test(sample1, sample2)
# Out:
# T-Statistic: -2.3981
# P-Value: 0.0197
# Reject the null hypothesis: The means are significantly different.

# %%
#7. Perform a paired sample T-test using Python and visualize the comparison results.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def paired_t_test(sample1, sample2, alpha=0.05):
    t_stat, p_value = stats.ttest_rel(sample1, sample2)

    print(f"T-Statistic: {t_stat:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant difference between paired samples.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between paired samples.")

    plt.figure(figsize=(6, 4))
    plt.scatter(sample1, sample2, color='blue', label="Paired Data Points")
    plt.plot([min(sample1), max(sample1)], [min(sample2), max(sample2)], 'r--', label="y = x Line")
    plt.xlabel("Before Treatment")
    plt.ylabel("After Treatment")
    plt.title("Paired Sample Comparison")
    plt.legend()
    plt.show()

np.random.seed(42)
before_treatment = np.random.normal(loc=50, scale=5, size=30)
after_treatment = before_treatment + np.random.normal(loc=2, scale=3, size=30)

paired_t_test(before_treatment, after_treatment)
# Out:
# T-Statistic: -3.2089
# P-Value: 0.0032
# Reject the null hypothesis: There is a significant difference between paired samples.

# %%
#8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

import numpy as np
import scipy.stats as stats

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    print(f"Z-Test: Z-Score = {z_score:.4f}, P-Value = {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis: Sample mean is significantly different from population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference.")

def t_test(sample, pop_mean, alpha=0.05):
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)

    print(f"T-Test: T-Statistic = {t_stat:.4f}, P-Value = {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis: Sample mean is significantly different from population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference.")

np.random.seed(42)
population_mean = 50
population_std = 10
sample_size = 30

sample = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)

print("Performing Z-Test:")
z_test(sample, pop_mean=population_mean, pop_std=population_std)

print("\nPerforming T-Test:")
t_test(sample, pop_mean=population_mean)
# Out:
# Performing Z-Test:
# Z-Test: Z-Score = -1.0305, P-Value = 0.3028
# Fail to reject the null hypothesis: No significant difference.
#
# Performing T-Test:
# T-Test: T-Statistic = -1.1450, P-Value = 0.2616
# Fail to reject the null hypothesis: No significant difference.

# %%
#9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

import numpy as np
import scipy.stats as stats

def confidence_interval(sample, confidence=0.95):
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)
    sample_size = len(sample)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size - 1) * (sample_std / np.sqrt(sample_size))
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({lower_bound:.4f}, {upper_bound:.4f})")
    return lower_bound, upper_bound

np.random.seed(42)
sample = np.random.normal(loc=50, scale=10, size=30)

confidence_interval(sample)
# Out:
# 95.0% Confidence Interval: (44.7579, 51.4792)
# (np.float64(44.75785181035169), np.float64(51.47921027262756))

# %%
#10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

import numpy as np
import scipy.stats as stats

def confidence_interval(sample, confidence=0.95):
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)
    sample_size = len(sample)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size - 1) * (sample_std / np.sqrt(sample_size))
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({lower_bound:.4f}, {upper_bound:.4f})")
    return lower_bound, upper_bound

np.random.seed(42)
sample = np.random.normal(loc=50, scale=10, size=30)

confidence_interval(sample)
# Out:
# 95.0% Confidence Interval: (44.7579, 51.4792)
# (np.float64(44.75785181035169), np.float64(51.47921027262756))

# %%
#11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

def bayes_theorem(prior, likelihood, marginal_likelihood):
    posterior = (likelihood * prior) / marginal_likelihood
    print(f"Posterior Probability: {posterior:.4f}")
    return posterior

prior_prob = 0.02
likelihood_given_evidence = 0.85
marginal_likelihood = (likelihood_given_evidence * prior_prob) + ((1 - prior_prob) * 0.10)

bayes_theorem(prior_prob, likelihood_given_evidence, marginal_likelihood)
# Out:
# Posterior Probability: 0.1478
# 0.14782608695652175

# %%
#12. Perform a Chi-square test for independence between two categorical variables in Python.

import numpy as np
import scipy.stats as stats
import pandas as pd

def chi_square_test(data):
    chi2, p_value, dof, expected = stats.chi2_contingency(data)

    print(f"Chi-Square Statistic: {chi2:.4f}")
    print(f"Degrees of Freedom: {dof}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < 0.05:
        print("Reject the null hypothesis: There is a significant relationship between the variables.")
    else:
        print("Fail to reject the null hypothesis: No significant relationship between the variables.")

data = np.array([[30, 10], [15, 25]])
chi_square_test(data)
# Out:
# Chi-Square Statistic: 9.9556
# Degrees of Freedom: 1
# P-Value: 0.0016
# Reject the null hypothesis: There is a significant relationship between the variables.

# %%
#13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

import numpy as np
import scipy.stats as stats

def calculate_expected_frequencies(observed):
    chi2, p, dof, expected = stats.chi2_contingency(observed)

    print("Observed Frequencies:")
    print(np.array(observed))
    print("\nExpected Frequencies:")
    print(np.round(expected, 2))

observed_data = np.array([[30, 10], [15, 25]])
calculate_expected_frequencies(observed_data)
# Out:
# Observed Frequencies:
# [[30 10]
#  [15 25]]
#
# Expected Frequencies:
# [[22.5 17.5]
#  [22.5 17.5]]

# %%
#14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

import numpy as np
import scipy.stats as stats

def goodness_of_fit_test(observed, expected):
    chi2, p_value = stats.chisquare(observed, expected)

    print(f"Chi-Square Statistic: {chi2:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < 0.05:
        print("Reject the null hypothesis: The observed data does not fit the expected distribution.")
    else:
        print("Fail to reject the null hypothesis: The observed data fits the expected distribution.")

observed_data = np.array([50, 30, 20])
expected_data = np.array([40, 40, 20])

goodness_of_fit_test(observed_data, expected_data)
# Out:
# Chi-Square Statistic: 5.0000
# P-Value: 0.0821
# Fail to reject the null hypothesis: The observed data fits the expected distribution.

# %%
#15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def visualize_chi_square(df_values, size=1000):
    x = np.linspace(0, 30, 1000)

    plt.figure(figsize=(8, 5))

    for df in df_values:
        chi_square_dist = stats.chi2.pdf(x, df)
        plt.plot(x, chi_square_dist, label=f"df={df}")

    plt.xlabel("Value")
    plt.ylabel("Probability Density")
    plt.title("Chi-Square Distribution for Different Degrees of Freedom")
    plt.legend()
    plt.show()

visualize_chi_square([2, 4, 6, 8])

# %%
#16.  Implement an F-test using Python to compare the variances of two random samples.

import numpy as np
import scipy.stats as stats

def f_test(sample1, sample2):
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)

    f_statistic = var1 / var2 if var1 > var2 else var2 / var1
    df1 = len(sample1) - 1
    df2 = len(sample2) - 1
    p_value = 1 - stats.f.cdf(f_statistic, df1, df2)

    print(f"F-Statistic: {f_statistic:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < 0.05:
        print("Reject the null hypothesis: The variances are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference in variances.")

np.random.seed(42)
sample1 = np.random.normal(50, 10, 30)
sample2 = np.random.normal(50, 15, 30)

f_test(sample1, sample2)
# Out:
# F-Statistic: 2.4082
# P-Value: 0.0104
# Reject the null hypothesis: The variances are significantly different.

# %%
#17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results.

import numpy as np
import scipy.stats as stats

def anova_test(*groups):
    f_statistic, p_value = stats.f_oneway(*groups)

    print(f"F-Statistic: {f_statistic:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between group means.")

np.random.seed(42)
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)
group3 = np.random.normal(60, 10, 30)

anova_test(group1, group2, group3)
# Out:
# F-Statistic: 12.2095
# P-Value: 0.0000
# Reject the null hypothesis: At least one group mean is significantly different.

# %%
#18.  Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def anova_test_and_plot(*groups):
    f_statistic, p_value = stats.f_oneway(*groups)

    print(f"F-Statistic: {f_statistic:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between group means.")

    plt.boxplot(groups, labels=[f"Group {i+1}" for i in range(len(groups))])
    plt.title("One-Way ANOVA Test Results")
    plt.xlabel("Groups")
    plt.ylabel("Values")
    plt.show()

np.random.seed(42)
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)
group3 = np.random.normal(60, 10, 30)

anova_test_and_plot(group1, group2, group3)
# Out:
# F-Statistic: 12.2095
# P-Value: 0.0000
# Reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-21-7303a16af808>:18: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f"Group {i+1}" for i in range(len(groups))])

# %%
#19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def check_anova_assumptions(*groups):
    print("Checking Assumptions for ANOVA:\n")

    # Normality Test (Shapiro-Wilk Test)
    for i, group in enumerate(groups):
        stat, p_value = stats.shapiro(group)
        print(f"Group {i+1} - Shapiro-Wilk Test: p = {p_value:.4f} {'(Fail to reject normality)' if p_value > 0.05 else '(Reject normality)'}")

    # Homogeneity of Variance Test (Levene’s Test)
    stat, p_value = stats.levene(*groups)
    print(f"\nLevene’s Test for Equal Variance: p = {p_value:.4f} {'(Fail to reject equal variance)' if p_value > 0.05 else '(Reject equal variance)'}")

    # Boxplot for Visual Inspection
    plt.boxplot(groups, labels=[f"Group {i+1}" for i in range(len(groups))])
    plt.title("Boxplot of Groups")
    plt.xlabel("Groups")
    plt.ylabel("Values")
    plt.show()

np.random.seed(42)
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)
group3 = np.random.normal(60, 10, 30)

check_anova_assumptions(group1, group2, group3)
# Out:
# Checking Assumptions for ANOVA:
#
# Group 1 - Shapiro-Wilk Test: p = 0.6868 (Fail to reject normality)
# Group 2 - Shapiro-Wilk Test: p = 0.9130 (Fail to reject normality)
# Group 3 - Shapiro-Wilk Test: p = 0.3654 (Fail to reject normality)
#
# Levene’s Test for Equal Variance: p = 0.8627 (Fail to reject equal variance)
# <ipython-input-22-589029643188>:20: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f"Group {i+1}" for i in range(len(groups))])

# %%
#20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results.

import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

def two_way_anova(data, factor1, factor2, response):
    model = smf.ols(f'{response} ~ C({factor1}) + C({factor2}) + C({factor1}):C({factor2})', data=data).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    print("\nTwo-Way ANOVA Results:\n", anova_table)

    sns.boxplot(x=factor1, y=response, hue=factor2, data=data)
    plt.title("Boxplot of Response Variable by Two Factors")
    plt.show

# %%
#21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def visualize_f_distribution(dfn, dfd):
    x = np.linspace(0, 5, 1000)
    y = stats.f.pdf(x, dfn, dfd)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label=f'F-Distribution (df1={dfn}, df2={dfd})', color='blue')
    plt.fill_between(x, y, alpha=0.3, color='blue')
    plt.axvline(stats.f.ppf(0.95, dfn, dfd), color='red', linestyle='dashed', label="Critical Value (α=0.05)")

    plt.xlabel("F-Statistic")
    plt.ylabel("Probability Density")
    plt.title("F-Distribution Visualization")
    plt.legend()
    plt.show()

visualize_f_distribution(dfn=5, dfd=10)

# %%
#22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

def one_way_anova(groups):
    f_statistic, p_value = stats.f_oneway(*groups)
    print(f"F-Statistic: {f_statistic:.4f}, P-Value: {p_value:.4f}")

    if p_value < 0.05:
        print("Result: Reject the null hypothesis (Significant difference between groups).")
    else:
        print("Result: Fail to reject the null hypothesis (No significant difference between groups).")

    data = []
    labels = []
    for i, group in enumerate(groups):
        data.extend(group)
        labels.extend([f"Group {i+1}"] * len(group))

    df = pd.DataFrame({"Value": data, "Group": labels})

    plt.figure(figsize=(8, 5))
    sns.boxplot(x="Group", y="Value", data=df)
    plt.title("Boxplot of Group Means")
    plt.show()

np.random.seed(42)
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)
group3 = np.random.normal(52, 10, 30)

one_way_anova([group1, group2, group3])
# Out:
# F-Statistic: 2.8740, P-Value: 0.0619
# Result: Fail to reject the null hypothesis (No significant difference between groups).

# %%
#23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.

import numpy as np
import scipy.stats as stats

def hypothesis_testing(sample_size=30, mu_population=50, sigma_population=10, alpha=0.05):
    np.random.seed(42)
    sample = np.random.normal(mu_population, sigma_population, sample_size)
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)

    z_statistic = (sample_mean - mu_population) / (sigma_population / np.sqrt(sample_size))
    z_p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))

    t_statistic, t_p_value = stats.ttest_1samp(sample, mu_population)

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-Test: Z-Statistic = {z_statistic:.4f}, P-Value = {z_p_value:.4f}")
    print(f"T-Test: T-Statistic = {t_statistic:.4f}, P-Value = {t_p_value:.4f}")

    if z_p_value < alpha:
        print("Z-Test Result: Reject the null hypothesis (Significant difference).")
    else:
        print("Z-Test Result: Fail to reject the null hypothesis (No significant difference).")

    if t_p_value < alpha:
        print("T-Test Result: Reject the null hypothesis (Significant difference).")
    else:
        print("T-Test Result: Fail to reject the null hypothesis (No significant difference).")

hypothesis_testing()
# Out:
# Sample Mean: 48.12
# Z-Test: Z-Statistic = -1.0305, P-Value = 0.3028
# T-Test: T-Statistic = -1.1450, P-Value = 0.2616
# Z-Test Result: Fail to reject the null hypothesis (No significant difference).
# T-Test Result: Fail to reject the null hypothesis (No significant difference).

# %%
#24.Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.

import numpy as np
import scipy.stats as stats

def variance_hypothesis_test(sample_size=30, sample_variance=20, population_variance=25, alpha=0.05):
    chi_square_stat = (sample_size - 1) * sample_variance / population_variance
    lower_critical = stats.chi2.ppf(alpha / 2, df=sample_size - 1)
    upper_critical = stats.chi2.ppf(1 - alpha / 2, df=sample_size - 1)
    p_value = 2 * min(stats.chi2.cdf(chi_square_stat, df=sample_size - 1),
                       1 - stats.chi2.cdf(chi_square_stat, df=sample_size - 1))

    print(f"Chi-Square Statistic: {chi_square_stat:.4f}")
    print(f"Critical Values: ({lower_critical:.4f}, {upper_critical:.4f})")
    print(f"P-Value: {p_value:.4f}")

    if chi_square_stat < lower_critical or chi_square_stat > upper_critical:
        print("Result: Reject the null hypothesis (Variance is significantly different).")
    else:
        print("Result: Fail to reject the null hypothesis (Variance is not significantly different).")

np.random.seed(42)
sample = np.random.normal(50, np.sqrt(20), 30)
sample_variance = np.var(sample, ddof=1)

variance_hypothesis_test(sample_size=30, sample_variance=sample_variance, population_variance=25, alpha=0.05)
# Out:
# Chi-Square Statistic: 18.7923
# Critical Values: (16.0471, 45.7223)
# P-Value: 0.1470
# Result: Fail to reject the null hypothesis (Variance is not significantly different).

# %%
#25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.

import numpy as np
import scipy.stats as stats

def z_test_proportions(success_a, size_a, success_b, size_b, alpha=0.05):
    p1 = success_a / size_a
    p2 = success_b / size_b
    pooled_p = (success_a + success_b) / (size_a + size_b)
    standard_error = np.sqrt(pooled_p * (1 - pooled_p) * (1/size_a + 1/size_b))

    z_statistic = (p1 - p2) / standard_error
    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))

    print(f"Proportion 1: {p1:.4f}, Proportion 2: {p2:.4f}")
    print(f"Z-Statistic: {z_statistic:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < alpha:
        print("Result: Reject the null hypothesis (Significant difference between proportions).")
    else:
        print("Result: Fail to reject the null hypothesis (No significant difference between proportions).")

z_test_proportions(success_a=45, size_a=100, success_b=30, size_b=100)
# Out:
# Proportion 1: 0.4500, Proportion 2: 0.3000
# Z-Statistic: 2.1909
# P-Value: 0.0285
# Result: Reject the null hypothesis (Significant difference between proportions).

# %%
#26.  Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def f_test_variance(data1, data2, alpha=0.05):
    var1 = np.var(data1, ddof=1)
    var2 = np.var(data2, ddof=1)

    f_statistic = var1 / var2 if var1 > var2 else var2 / var1
    dfn = len(data1) - 1
    dfd = len(data2) - 1

    p_value = 2 * min(1 - stats.f.cdf(f_statistic, dfn, dfd), stats.f.cdf(f_statistic, dfn, dfd))

    print(f"Variance 1: {var1:.4f}, Variance 2: {var2:.4f}")
    print(f"F-Statistic: {f_statistic:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < alpha:
        print("Result: Reject the null hypothesis (Variances are significantly different).")
    else:
        print("Result: Fail to reject the null hypothesis (No significant difference in variances).")

    x = np.linspace(0.1, 5, 500)
    f_dist = stats.f.pdf(x, dfn, dfd)

    plt.figure(figsize=(8, 5))
    plt.plot(x, f_dist, label=f"F-Distribution (dfn={dfn}, dfd={dfd})", color='blue')
    plt.axvline(f_statistic, color='red', linestyle='dashed', label=f"F-Statistic: {f_statistic:.2f}")
    plt.fill_between(x, f_dist, where=(x > stats.f.ppf(1 - alpha / 2, dfn, dfd)), color='red', alpha=0.3)

# %%
#27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def chi_square_goodness_of_fit(observed, expected, alpha=0.05):
    chi_stat, p_value = stats.chisquare(observed, expected)

    print(f"Chi-Square Statistic: {chi_stat:.4f}")
    print(f"P-Value: {p_value:.4f}")

    if p_value < alpha:
        print("Result: Reject the null hypothesis (Observed distribution differs significantly from expected).")
    else:
        print("Result: Fail to reject the null hypothesis (No significant difference between observed and expected).")

    categories = np.arange(len(observed))
    plt.figure(figsize=(8, 5))
    plt.bar(categories - 0.2, observed, width=0.4, label="Observed", color='blue', alpha=0.7)
    plt.bar(categories + 0.2, expected, width=0.4, label="Expected", color='orange', alpha=0.7)

    plt.xlabel("Categories")
    plt.ylabel("Frequency")
    plt.title("Chi-Square Goodness of Fit Test")
    plt.legend()
    plt
